# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test data shape:", x_test.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Training data shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test data shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)

# %%
class_names = [
    'airplane', 'automobile', 'bird', 'cat', 'deer',
    'dog', 'frog', 'horse', 'ship', 'truck'
]
# Normalize pixel values (0–255 → 0–1)
x_train = x_train / 255.0
x_test = x_test / 255.0
# Convert labels to one-hot encoding
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# %%
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis('off')
plt.show()

# %%
baseline_model = models.Sequential()

# First Convolution Block
baseline_model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
baseline_model.add(layers.MaxPooling2D((2,2)))

# Second Convolution Block
baseline_model.add(layers.Conv2D(64, (3,3), activation='relu'))
baseline_model.add(layers.MaxPooling2D((2,2)))

# Flatten + Dense
baseline_model.add(layers.Flatten())
baseline_model.add(layers.Dense(64, activation='relu'))
baseline_model.add(layers.Dense(10, activation='softmax'))

baseline_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 167,562 (654.54 KB)
#  Trainable params: 167,562 (654.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
baseline_model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_baseline = baseline_model.fit(
    x_train, y_train_cat,
    epochs=15,
    batch_size=64,
    validation_data=(x_test, y_test_cat)
)
# Out:
# Epoch 1/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - accuracy: 0.3635 - loss: 1.7456 - val_accuracy: 0.5516 - val_loss: 1.2557
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5662 - loss: 1.2268 - val_accuracy: 0.6195 - val_loss: 1.0951
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6262 - loss: 1.0627 - val_accuracy: 0.6425 - val_loss: 1.0361
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6691 - loss: 0.9503 - val_accuracy: 0.6611 - val_loss: 0.9823
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.6908 - loss: 0.8916 - val_accuracy: 0.6794 - val_loss: 0.9249
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7096 - loss: 0.8402 - val_accuracy: 0.6742 - val_loss: 0.9544
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7256 - loss: 0.7926 - val_accuracy: 0.6969 - val_loss: 0.9018
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7377 - loss: 0.7514 - val_accuracy: 0.6918 - val_loss: 0.9132
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7535 - loss: 0.7032 - val_accuracy: 0.6968 - val_loss: 0.8844
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7645 - loss: 0.6798 - val_accuracy: 0.6914 - val_loss: 0.9242
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7743 - loss: 0.6446 - val_accuracy: 0.7025 - val_loss: 0.8953
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7858 - loss: 0.6117 - val_accuracy: 0.6959 - val_loss: 0.9262
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7942 - loss: 0.5876 - val_accuracy: 0.7039 - val_loss: 0.9340
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8091 - loss: 0.5497 - val_accuracy: 0.6997 - val_loss: 0.9262
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8162 - loss: 0.5259 - val_accuracy: 0.7021 - val_loss: 0.9231

# %%
test_loss, test_acc = baseline_model.evaluate(x_test, y_test_cat)
print("Baseline Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7029 - loss: 0.9129
# Baseline Test Accuracy: 0.7020999789237976

# %%
plt.figure(figsize=(8,5))
plt.plot(history_baseline.history['accuracy'], label='Train Accuracy')
plt.plot(history_baseline.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Baseline Model Accuracy')
plt.show()


plt.figure(figsize=(8,5))
plt.plot(history_baseline.history['loss'], label='Train Loss')
plt.plot(history_baseline.history['val_loss'], label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Baseline Model Loss')
plt.show()

# %%
improved_model = models.Sequential()

# Block 1
improved_model.add(layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
improved_model.add(layers.BatchNormalization())
improved_model.add(layers.MaxPooling2D((2,2)))

# Block 2
improved_model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
improved_model.add(layers.BatchNormalization())
improved_model.add(layers.MaxPooling2D((2,2)))

# Block 3 (New)
improved_model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
improved_model.add(layers.BatchNormalization())
improved_model.add(layers.MaxPooling2D((2,2)))

# Classifier
improved_model.add(layers.Flatten())
improved_model.add(layers.Dense(128, activation='relu'))
improved_model.add(layers.Dropout(0.5))
improved_model.add(layers.Dense(10, activation='softmax'))

improved_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 357,706 (1.36 MB)
#  Trainable params: 357,258 (1.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
improved_model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)

datagen.fit(x_train)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(
    monitor='val_accuracy',   # better for classification
    patience=10,              # was too small before
    restore_best_weights=True
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-5
)

# %%
history_aug = improved_model.fit(
    datagen.flow(x_train, y_train_cat, batch_size=64),
    epochs=40,
    validation_data=(x_test, y_test_cat),
    callbacks=[early_stop, lr_scheduler]
)
# Out:
# Epoch 1/40
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 43ms/step - accuracy: 0.6721 - loss: 1.0467 - val_accuracy: 0.7523 - val_loss: 0.8146 - learning_rate: 0.0010
# Epoch 2/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7134 - loss: 0.8624 - val_accuracy: 0.7576 - val_loss: 0.7548 - learning_rate: 0.0010
# Epoch 3/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7288 - loss: 0.8129 - val_accuracy: 0.7686 - val_loss: 0.7313 - learning_rate: 0.0010
# Epoch 4/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7445 - loss: 0.7711 - val_accuracy: 0.7465 - val_loss: 0.7604 - learning_rate: 0.0010
# Epoch 5/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7421 - loss: 0.7655 - val_accuracy: 0.7897 - val_loss: 0.6426 - learning_rate: 0.0010
# Epoch 6/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.7549 - loss: 0.7295 - val_accuracy: 0.7479 - val_loss: 0.8022 - learning_rate: 0.0010
# Epoch 7/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7619 - loss: 0.7171 - val_accuracy: 0.7744 - val_loss: 0.6947 - learning_rate: 0.0010
# Epoch 8/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7610 - loss: 0.7137 - val_accuracy: 0.7720 - val_loss: 0.7045 - learning_rate: 0.0010
# Epoch 9/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7688 - loss: 0.6916 - val_accuracy: 0.7907 - val_loss: 0.6696 - learning_rate: 0.0010
# Epoch 10/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7615 - loss: 0.7007 - val_accuracy: 0.7896 - val_loss: 0.6396 - learning_rate: 0.0010
# Epoch 11/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7743 - loss: 0.6808 - val_accuracy: 0.7520 - val_loss: 0.7905 - learning_rate: 0.0010
# Epoch 12/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7715 - loss: 0.6662 - val_accuracy: 0.7703 - val_loss: 0.7094 - learning_rate: 0.0010
# Epoch 13/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 41ms/step - accuracy: 0.7747 - loss: 0.6700 - val_accuracy: 0.8057 - val_loss: 0.5866 - learning_rate: 0.0010
# Epoch 14/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7781 - loss: 0.6567 - val_accuracy: 0.7898 - val_loss: 0.6418 - learning_rate: 0.0010
# Epoch 15/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.7811 - loss: 0.6416 - val_accuracy: 0.7776 - val_loss: 0.6849 - learning_rate: 0.0010
# Epoch 16/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.7844 - loss: 0.6443 - val_accuracy: 0.7990 - val_loss: 0.6305 - learning_rate: 0.0010
# Epoch 17/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7892 - loss: 0.6287 - val_accuracy: 0.7613 - val_loss: 0.7467 - learning_rate: 0.0010
# Epoch 18/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.7859 - loss: 0.6297 - val_accuracy: 0.7939 - val_loss: 0.6276 - learning_rate: 0.0010
# Epoch 19/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7984 - loss: 0.6015 - val_accuracy: 0.8103 - val_loss: 0.5719 - learning_rate: 5.0000e-04
# Epoch 20/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8056 - loss: 0.5829 - val_accuracy: 0.8260 - val_loss: 0.5291 - learning_rate: 5.0000e-04
# Epoch 21/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8057 - loss: 0.5722 - val_accuracy: 0.8167 - val_loss: 0.5481 - learning_rate: 5.0000e-04
# Epoch 22/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8084 - loss: 0.5662 - val_accuracy: 0.8245 - val_loss: 0.5319 - learning_rate: 5.0000e-04
# Epoch 23/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8147 - loss: 0.5531 - val_accuracy: 0.8093 - val_loss: 0.5809 - learning_rate: 5.0000e-04
# Epoch 24/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8152 - loss: 0.5513 - val_accuracy: 0.8156 - val_loss: 0.5661 - learning_rate: 5.0000e-04
# Epoch 25/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8121 - loss: 0.5443 - val_accuracy: 0.8097 - val_loss: 0.5677 - learning_rate: 5.0000e-04
# Epoch 26/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8222 - loss: 0.5264 - val_accuracy: 0.8175 - val_loss: 0.5562 - learning_rate: 2.5000e-04
# Epoch 27/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8232 - loss: 0.5239 - val_accuracy: 0.8207 - val_loss: 0.5576 - learning_rate: 2.5000e-04
# Epoch 28/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8249 - loss: 0.5161 - val_accuracy: 0.8372 - val_loss: 0.4943 - learning_rate: 2.5000e-04
# Epoch 29/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8280 - loss: 0.5080 - val_accuracy: 0.8347 - val_loss: 0.5059 - learning_rate: 2.5000e-04
# Epoch 30/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.8267 - loss: 0.5106 - val_accuracy: 0.8333 - val_loss: 0.5087 - learning_rate: 2.5000e-04
# Epoch 31/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8254 - loss: 0.5182 - val_accuracy: 0.8316 - val_loss: 0.5109 - learning_rate: 2.5000e-04
# Epoch 32/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 37ms/step - accuracy: 0.8272 - loss: 0.5084 - val_accuracy: 0.8241 - val_loss: 0.5331 - learning_rate: 2.5000e-04
# Epoch 33/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8288 - loss: 0.5060 - val_accuracy: 0.8306 - val_loss: 0.5195 - learning_rate: 2.5000e-04
# Epoch 34/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8335 - loss: 0.4965 - val_accuracy: 0.8334 - val_loss: 0.5095 - learning_rate: 1.2500e-04
# Epoch 35/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8292 - loss: 0.5018 - val_accuracy: 0.8376 - val_loss: 0.4949 - learning_rate: 1.2500e-04
# Epoch 36/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 38ms/step - accuracy: 0.8351 - loss: 0.4898 - val_accuracy: 0.8326 - val_loss: 0.5074 - learning_rate: 1.2500e-04
# Epoch 37/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8343 - loss: 0.4932 - val_accuracy: 0.8308 - val_loss: 0.5093 - learning_rate: 1.2500e-04
# Epoch 38/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.8317 - loss: 0.4921 - val_accuracy: 0.8336 - val_loss: 0.5103 - learning_rate: 1.2500e-04
# Epoch 39/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 38ms/step - accuracy: 0.8351 - loss: 0.4861 - val_accuracy: 0.8333 - val_loss: 0.5012 - learning_rate: 6.2500e-05
# Epoch 40/40
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8336 - loss: 0.4862 - val_accuracy: 0.8392 - val_loss: 0.4827 - learning_rate: 6.2500e-05

# %%
test_loss_improved, test_acc_improved = improved_model.evaluate(x_test, y_test_cat)
print("Improved Model Test Accuracy:", test_acc_improved)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8369 - loss: 0.4983
# Improved Model Test Accuracy: 0.8392000198364258

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predictions
y_pred = improved_model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = y_test.flatten()

# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Improved CNN")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step

# %%
plt.figure(figsize=(8,5))
plt.plot(history_improved.history['accuracy'], label='Train Accuracy')
plt.plot(history_improved.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title("Improved Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()


plt.figure(figsize=(8,5))
plt.plot(history_improved.history['loss'], label='Train Loss')
plt.plot(history_improved.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Improved Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
print("Baseline Accuracy:", test_acc)
print("Improved Accuracy:", test_acc_improved)
print("Improvement:", test_acc_improved - test_acc)
# Out:
# Baseline Accuracy: 0.7020999789237976
# Improved Accuracy: 0.8392000198364258
# Improvement: 0.13710004091262817

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/cifar10_project
